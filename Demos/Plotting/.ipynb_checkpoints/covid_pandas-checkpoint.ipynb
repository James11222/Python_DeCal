# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['font.size'] = 22

# %%
covid_df = pd.read_csv('Covid_Data.csv')

covid_df

# covid_df['total_cases']
# Out:
#         date  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 0     1/1/20            0          0               0.000             0
# 1     1/2/20            0          0               0.000             0
# 2     1/3/20            0          0               0.000             0
# 3     1/4/20            0          0               0.000             0
# 4     1/5/20            0          0               0.000             0
# ..       ...          ...        ...                 ...           ...
# 262  9/19/20      6724667      50209           39911.286        198589
# 263  9/20/20      6764962      40295           39836.286        199258
# 264  9/21/20      6804814      39852           40690.714        199509
# 265  9/22/20      6857967      53153           43306.714        199881
# 266  9/23/20      6896274      38307           41425.857        200807
#
#      new_deaths  new_deaths_smoothed  total_cases_per_million  \
# ...

# %%
months=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'Jul', 'Aug', 'Oct']
locations = [1,33,62,93,123,154,184,215,247]

f, (ax1,ax2) = plt.subplots(1,2, figsize=(20,6))

ax1.set_title("New Cases and Deaths in 2020")
ax1.plot(covid_df['new_cases'], 'b.')
ax1.plot(covid_df['new_cases_smoothed'], 'b-')
ax1.plot(covid_df['new_deaths'], 'r.')
ax1.plot(covid_df['new_deaths_smoothed'], 'r-')
ax1.set_xticks(locations)
ax1.set_xticklabels(months)
ax1.grid()

ax2.set_title("Total Cases and Deaths in 2020")
ax2.plot(covid_df['total_cases'], 'b.')
# ax2.plot(covid_df['new_cases_smoothed'], 'b-')
ax2.plot(covid_df['total_deaths'], 'r.')
# ax2.plot(covid_df['new_deaths_smoothed'], 'r-')
ax2.set_xticks(locations)
ax2.set_xticklabels(months)
ax2.grid()

f.tight_layout()

# %%
months=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'Jul', 'Aug', 'Oct']
locations = [1,33,62,93,123,154,184,215,247]

# %%
dates_dict = {'Months':months, 'Indeces':locations}

# %%
date_locations_df = pd.DataFrame(dates_dict)

date_locations_df
# Out:
#   Months  Indeces
# 0    Jan        1
# 1    Feb       33
# 2    Mar       62
# 3    Apr       93
# 4    May      123
# 5   June      154
# 6    Jul      184
# 7    Aug      215
# 8    Oct      247

# %%
date_locations_df.to_csv('date_locations_demo.csv')
